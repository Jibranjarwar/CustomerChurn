# %%
import pandas as pd
import sys
from sqlalchemy import create_engine
import os
from dotenv import load_dotenv
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
import numpy as np
import random
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score

sys.path.append('../')
from modeling.features import get_features_and_target, FEATURE_COLUMNS
from modeling.config import model_config

load_dotenv()
# Out:
# True

# %%
engine = create_engine(
    f"postgresql+psycopg://{os.getenv('DB_USER')}:{os.getenv('DB_PASSWORD')}@{os.getenv('DB_HOST')}:{os.getenv('DB_PORT')}/{os.getenv('DB_NAME')}"
)

# %%
df = pd.read_sql("SELECT * FROM customers", engine)
df.head()
# Out:
#    customer_id signup_date last_active_date  monthly_spend  \
# 0            1  2023-10-19       2023-10-19         383.70
# 1            2  2025-04-21       2025-07-07         295.41
# 2            3  2025-04-30       2025-04-30         277.41
# 3            4  2023-10-08       2025-07-22         149.20
# 4            5  2023-05-01       2023-05-01         240.18
#
#    monthly_spend_last_month  support_tickets  logins_last_30_days  churned  \
# 0                    344.55                1                   23     True
# 1                    306.10                0                    0    False
# 2                    224.87                1                   22     True
# 3                    154.53                0                   24    False
# 4                    218.84                1                   30     True
#
#    tenure_days tenure_bucket  ...  tickets_per_tenure  logins_per_day  \
# 0          655          1-2y  ...            0.001524        0.766667
# ...

# %%
print(f"Data shape: {df.shape}")
print(f"Missing values: {df.isnull().sum().sum()}")
print(f"Duplicates: {df.duplicated().sum()}")

df.info()
df.describe()
df['churned'].value_counts(normalize=True)
# Out:
# Data shape: (1000, 21)
# Missing values: 0
# Duplicates: 0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               1000 non-null   int64
#  1   signup_date               1000 non-null   datetime64[ns]
#  2   last_active_date          1000 non-null   object
#  3   monthly_spend             1000 non-null   float64
#  4   monthly_spend_last_month  1000 non-null   float64
#  5   support_tickets           1000 non-null   int64
#  6   logins_last_30_days       1000 non-null   int64
#  7   churned                   1000 non-null   bool
#  8   tenure_days               1000 non-null   int64
#  9   tenure_bucket             1000 non-null   object
#  10  spend_change              1000 non-null   float64
#  11  tickets_per_tenure        1000 non-null   float64
# ...

# %%
df.corr(numeric_only=True)
df.groupby('churned').mean(numeric_only=True)
# Out:
#          customer_id  monthly_spend  monthly_spend_last_month  \
# churned
# False     510.635838     264.370751                264.942399
# True      477.727273     287.218117                288.976494
#
#          support_tickets  logins_last_30_days  tenure_days  spend_change  \
# churned
# False           2.500000            14.518786   516.647399     -0.571647
# True            2.571429            15.831169   511.551948     -1.758377
#
#          tickets_per_tenure  logins_per_day  tickets_per_month  \
# churned
# False              0.018474        0.483960           0.344987
# True               0.011957        0.527706           0.333495
#
#          logins_last_60_days  login_trend  tenure_bucket_<3m  \
# churned
# False              29.514451    -0.476879           0.083815
# True               30.646104     1.016234           0.084416
#
#          tenure_bucket_3-6m  tenure_bucket_6-12m  tenure_bucket_1-2y  \
# churned
# ...

# %%
X, y = get_features_and_target(df)

print(f"Features: {len(X.columns)}")
print(f"Target distribution: {y.value_counts(normalize=True).to_dict()}")

model_data = pd.concat([X, y], axis=1)
model_data.to_csv("../data/processed/customers_clean.csv", index=False)
# Out:
# Engineering advanced features for churn prediction...
# Added 8 new features
# New features: interaction, time-based, and customer segments
# Using 24 features: ['monthly_spend', 'spend_change', 'monthly_spend_last_month', 'logins_last_30_days', 'logins_last_60_days', 'logins_per_day', 'login_trend', 'support_tickets', 'tickets_per_month', 'tickets_per_tenure', 'tenure_days', 'tenure_bucket_<3m', 'tenure_bucket_3-6m', 'tenure_bucket_6-12m', 'tenure_bucket_1-2y', 'tenure_bucket_2y+', 'spend_login_interaction', 'spend_support_interaction', 'tenure_engagement_interaction', 'login_frequency_trend', 'is_high_value', 'is_active_user', 'is_support_heavy', 'customer_segment']
# Features: 24
# Target distribution: {0: 0.692, 1: 0.308}

# %%
correlations = X.corrwith(y).abs().sort_values(ascending=False)
print(correlations.head(10))

print(f"Data leakage check - monthly_spend_last_month correlation: {df['monthly_spend_last_month'].corr(df['churned']):.3f}")

plt.figure(figsize=(12, 8))
sns.heatmap(X.corr(), annot=True, cmap='coolwarm', center=0)
plt.title('Feature Correlation Matrix')
plt.tight_layout()
plt.show()

sns.boxplot(x='churned', y='monthly_spend', data=df)
plt.title("Monthly Spend vs Churn")
plt.show()
# Out:
# monthly_spend_last_month    0.083819
# monthly_spend               0.083016
# is_active_user              0.077000
# logins_last_30_days         0.067416
# logins_per_day              0.067416
# is_high_value               0.061733
# login_frequency_trend       0.053321
# login_trend                 0.053321
# tickets_per_tenure          0.042605
# logins_last_60_days         0.041635
# dtype: float64
# Data leakage check - monthly_spend_last_month correlation: 0.084

# %%
for col in ["logins_per_day", "tickets_per_month", "spend_change"]:
    print(f"{col} by churned status:")
    print(df.groupby("churned")[col].describe())
# Out:
# logins_per_day by churned status:
#          count      mean       std  min       25%       50%       75%  max
# churned
# False    692.0  0.483960  0.299495  0.0  0.233333  0.466667  0.733333  1.0
# True     308.0  0.527706  0.298514  0.0  0.266667  0.566667  0.800000  1.0
# tickets_per_month by churned status:
#          count      mean       std  min       25%       50%      75%       max
# churned
# False    692.0  0.344987  0.655650  0.0  0.054877  0.148181  0.30789  5.000000
# True     308.0  0.333495  0.550092  0.0  0.065713  0.141426  0.30303  2.926829
# spend_change by churned status:
#          count      mean        std    min      25%    50%      75%    max
# churned
# False    692.0 -0.571647  33.209507 -91.47 -20.4800 -0.350  21.2775  89.36
# True     308.0 -1.758377  34.944536 -91.02 -23.2125 -1.005  21.2950  88.41
